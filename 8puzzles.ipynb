# %%
def print_in_format(matrix):
    for i in range(9):
        if i%3 == 0 and i > 0:
            print("")
        print(str(matrix[i])+" ", end = "")

def count(s):
    c = 0
    ideal = [1, 2, 3,
             4, 5, 6,
             7, 8, 0]

    for i in range(9):
        if s[i] != 0 and s[i] != ideal[i]:
            c += 1

    return c


def move(ar, p, st):
    rh = 999999
    store_st = st.copy()

    for i in range(len(ar)):
        dupl_st = st.copy()

        temp = dupl_st[p]
        dupl_st[p] = dupl_st[arr[i]]
        dupl_st[arr[i]] = temp

        tmp_rh = count(dupl_st)

        if tmp_rh < rh:
            rh = tmp_rh
            store_st = dupl_st.copy()
    
    return store_st, rh
            

state = [1, 2, 3,
         0, 5, 6,
         4, 7, 8]

h = count(state)
Level = 1

print("\n------ Level "+str(Level)+" ------")
print_in_format(state)
print("\nHeuristic Value(Misplaced) : "+str(h))


while h>0:
    pos = int(state.index(0))

    Level += 1

    if pos == 0:
        arr = [1, 3]
        state, h = move(arr, pos, state)
    elif pos == 1:
        arr = [0, 2, 4]
        state, h = move(arr, pos, state)
    elif pos == 2:
        arr = [1, 5]
        state, h = move(arr, pos, state)
    elif pos == 3:
        arr = [0, 4, 6]
        state, h = move(arr, pos, state)
    elif pos == 4:
        arr = [1, 3, 5, 7]
        state, h = move(arr, pos, state)
    elif pos == 5:
        arr = [2, 4, 8]
        state, h = move(arr, pos, state)
    elif pos == 6:
        arr = [3, 7]
        state, h = move(arr, pos, state)
    elif pos == 7:
        arr = [4, 6, 8]
        state, h = move(arr, pos, state)
    elif pos == 8:
        arr = [5, 6]
        state, h = move(arr, pos, state)

    print("\n------ Level "+str(Level)+" ------")
    print_in_format(state)
    print("\nHeuristic Value(Misplaced) : "+str(h))
# Out:
# ------ Level 1 ------
# 1 2 3
# 8 5 6
# 4 7 0
# Heuristic Value(Misplaced) : 3
#
# ------ Level 2 ------
# 1 2 3
# 8 5 6
# 0 7 4
# Heuristic Value(Misplaced) : 3
#
# ------ Level 3 ------
# 1 2 3
# 8 5 6
# 7 0 4
# Heuristic Value(Misplaced) : 2
#
# ------ Level 4 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 5 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 6 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 7 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 8 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 9 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 10 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 11 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 12 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 13 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 14 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 15 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 16 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 17 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 18 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 19 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 20 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 21 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 22 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 23 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 24 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 25 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 26 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 27 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 28 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 29 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 30 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 31 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 32 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 33 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 34 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 35 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 36 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 37 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 38 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 39 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 40 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 41 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 42 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 43 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 44 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 45 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 46 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 47 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 48 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 49 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 50 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 51 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 52 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 53 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 54 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 55 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 56 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 57 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 58 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 59 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 60 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 61 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 62 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 63 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 64 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 65 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 66 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 67 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 68 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 69 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 70 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 71 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 72 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 73 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 74 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 75 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 76 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 77 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 78 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 79 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 80 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 81 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 82 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 83 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 84 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 85 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 86 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 87 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 88 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 89 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 90 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 91 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 92 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 93 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 94 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 95 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 96 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 97 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 98 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 99 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 100 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 101 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 102 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level
------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 5008 ------
# 1 2 3
# 8 5 6
# 7 4 0
# Heuristic Value(Misplaced) : 2
#
# ------ Level 5009 ------
# 1 2 3
# 8 5 0
# 7 4 6
# Heuristic Value(Misplaced) : 3
#
# ------ Level 5010 ------
# 1 2 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\visha\Desktop\vishal\AI\python\8puzzles.ipynb Cell 1 in <cell line: 52>()
#      <a href='vscode-notebook-cell:/c%3A/Users/visha/Desktop/vishal/AI/python/8puzzles.ipynb#ch0000000?line=82'>83</a>     state, h = move(arr, pos, state)
#      <a href='vscode-notebook-cell:/c%3A/Users/visha/Desktop/vishal/AI/python/8puzzles.ipynb#ch0000000?line=84'>85</a> print("\n------ Level "+str(Level)+" ------")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/visha/Desktop/vishal/AI/python/8puzzles.ipynb#ch0000000?line=85'>86</a> print_in_format(state)
#      <a href='vscode-notebook-cell:/c%3A/Users/visha/Desktop/vishal/AI/python/8puzzles.ipynb#ch0000000?line=86'>87</a> print("\nHeuristic Value(Misplaced) : "+str(h))
#
# c:\Users\visha\Desktop\vishal\AI\python\8puzzles.ipynb Cell 1 in print_in_format(matrix)
#       <a href='vscode-notebook-cell:/c%3A/Users/visha/Desktop/vishal/AI/python/8puzzles.ipynb#ch0000000?line=1'>2</a> for i in range(9):
#       <a href='vscode-notebook-cell:/c%3A/Users/visha/Desktop/vishal/AI/python/8puzzles.ipynb#ch0000000?line=2'>3</a>     if i%3 == 0 and i > 0:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/visha/Desktop/vishal/AI/python/8puzzles.ipynb#ch0000000?line=3'>4</a>         print("")
#       <a href='vscode-notebook-cell:/c%3A/Users/visha/Desktop/vishal/AI/python/8puzzles.ipynb#ch0000000?line=4'>5</a>     print(str(matrix[i])+" ", end = "")
#
# File c:\Users\visha\miniconda3\envs\datascience\lib\site-packages\ipykernel\iostream.py:531, in OutStream.write(self, string)
#     529 is_child = (not self._is_master_process())
#     530 # only touch the buffer in the IO thread to avoid races
# --> 531 self.pub_thread.schedule(lambda: self._buffer.write(string))
#     532 if is_child:
#     533     # mp.Pool cannot be trusted to flush promptly (or ever),
#     534     # and this helps.
#     535     if self._subprocess_flush_pending:
#
# File c:\Users\visha\miniconda3\envs\datascience\lib\site-packages\ipykernel\iostream.py:216, in IOPubThread.schedule(self, f)
#     214     self._events.append(f)
#     215     # wake event thread (message content is ignored)
# --> 216     self._event_pipe.send(b'')
#     217 else:
#     218     f()
#
# File c:\Users\visha\miniconda3\envs\datascience\lib\site-packages\zmq\sugar\socket.py:618, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     611         data = zmq.Frame(
#     612             data,
#     613             track=track,
#     614             copy=copy or None,
#     615             copy_threshold=self.copy_threshold,
#     616         )
#     617     data.group = group
# --> 618 return super().send(data, flags=flags, copy=copy, track=track)
#
# File zmq\backend\cython\socket.pyx:740, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:787, in zmq.backend.cython.socket.Socket.send()
#
# File zmq\backend\cython\socket.pyx:244, in zmq.backend.cython.socket._send_copy()
#
# File c:\Users\visha\miniconda3\envs\datascience\lib\site-packages\zmq\backend\cython\checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
